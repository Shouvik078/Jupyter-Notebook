# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x218f5a22210>)

# %%
covid_df=pd.read_csv('italy-covid-daywise.csv')

# %% [markdown]
# see the type

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df['date'].nunique()
# Out:
# 248

# %% [markdown]
# info () - for basic information

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# view statistical information

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %% [markdown]
# .at(index,column_name) - to see the value

# %%
covid_df.at[246,'new_cases']
# Out:
# 975.0

# %% [markdown]
# only show the some portion

# %%
date_extract=covid_df[['date','new_cases']]

# %%
date_extract
# Out:
#            date  new_cases
# 0    2019-12-31        0.0
# 1    2020-01-01        0.0
# 2    2020-01-02        0.0
# 3    2020-01-03        0.0
# 4    2020-01-04        0.0
# ..          ...        ...
# 243  2020-08-30     1444.0
# 244  2020-08-31     1365.0
# 245  2020-09-01      996.0
# 246  2020-09-02      975.0
# 247  2020-09-03     1326.0
#
# [248 rows x 2 columns]

# %% [markdown]
# head(row_length) - by default it 0, to see the only top result

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %% [markdown]
# tail() - to see the bottom results

# %%
covid_df.tail()
# Out:
#            date  new_cases  new_deaths  new_tests
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN

# %% [markdown]
# aggregate we can see

# %%
total_cases=covid_df.new_cases.sum() 
total_cases
# Out:
# 271515.0

# %%
total_deaths=covid_df.new_deaths.sum() 
total_deaths
# Out:
# 35497.0

# %%
round(total_deaths/total_cases*100,2)
# Out:
# 13.07

# %%
initial_case=935310
total_test=initial_case+covid_df.new_tests.sum() 
total_test
# Out:
# 5214766.0

# %%
positive_rate=total_cases/total_test

# %%
positive_rate *100
# Out:
# 5.206657403227681

# %% [markdown]
# Filtering

# %%
high_new_cases=covid_df.new_cases>1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %% [markdown]
# Applying filtering

# %%
covid_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
covid_df['positive_rate']=covid_df.new_cases/ covid_df.new_tests

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 1    2020-01-01        0.0         0.0        NaN            NaN
# 2    2020-01-02        0.0         0.0        NaN            NaN
# 3    2020-01-03        0.0         0.0        NaN            NaN
# 4    2020-01-04        0.0         0.0        NaN            NaN
# ..          ...        ...         ...        ...            ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055
# 245  2020-09-01      996.0         6.0    54395.0       0.018311
# 246  2020-09-02      975.0         8.0        NaN            NaN
# 247  2020-09-03     1326.0         6.0        NaN            NaN
#
# [248 rows x 5 columns]

# %% [markdown]
# drop columns, inpact=True means from the same dataset

# %%
covid_df.drop(columns=['positive_rate'],inplace=True)

# %% [markdown]
# sort_values('column_name',ascending=False means in decending order)

# %%
covid_df.sort_values('new_cases',ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 82  2020-03-22     6557.0       795.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 86  2020-03-26     5210.0       685.0        NaN

# %% [markdown]
# .loc() - used for slicing

# %%
covid_df.loc[169:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 169  2020-06-17      210.0        34.0    33957.0
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20     -148.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0
# 174  2020-06-22      224.0        24.0    16152.0
# 175  2020-06-23      221.0        23.0    23225.0

# %% [markdown]
# .to_datetime() - changing data types

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
covid_df['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
covid_df['year']=pd.DatetimeIndex(covid_df.date).year 
covid_df['month']=pd.DatetimeIndex(covid_df.date).month 
covid_df['day']=pd.DatetimeIndex(covid_df.date).day 
covid_df['weekday']=pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %%
covid_df_may=covid_df[covid_df.month==5] 
covid_df_may
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 122 2020-05-01     1872.0       285.0    43732.0  2020      5    1        4
# 123 2020-05-02     1965.0       269.0    31231.0  2020      5    2        5
# 124 2020-05-03     1900.0       474.0    27047.0  2020      5    3        6
# 125 2020-05-04     1389.0       174.0    22999.0  2020      5    4        0
# 126 2020-05-05     1221.0       195.0    32211.0  2020      5    5        1
# 127 2020-05-06     1075.0       236.0    37771.0  2020      5    6        2
# 128 2020-05-07     1444.0       369.0    13665.0  2020      5    7        3
# 129 2020-05-08     1401.0       274.0    45428.0  2020      5    8        4
# 130 2020-05-09     1327.0       243.0    36091.0  2020      5    9        5
# 131 2020-05-10     1083.0       194.0    31384.0  2020      5   10        6
# 132 2020-05-11      802.0       165.0    25823.0  2020      5   11        0
# ...

# %% [markdown]
# Extract only specific columns

# %%
covid_df_may_metrics=covid_df_may[['new_cases','new_deaths','new_tests']]

# %%
covid_df_may_metrics
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# ...

# %% [markdown]
# Then aggregate those columns

# %%
covid_may_totals=covid_df_may_metrics.sum() 
covid_may_totals
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %% [markdown]
# above three step code in one line

# %%
covid_df[covid_df.month==5][['new_cases','new_deaths','new_tests']].sum()
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
# Average for Sundays 
covid_df[covid_df.weekday==6].new_cases.mean()
# Out:
# 1247.2571428571428

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         7772.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %% [markdown]
# From above dataframe, now we can etract by using .loc

# %%
covid_month_df.loc[5]
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# Name: 5, dtype: float64

# %% [markdown]
# cumsum() - for cumulative sum

# %%
covid_df['total_cases']=covid_df.new_cases.cumsum() 
covid_df['total_deaths']=covid_df.new_deaths.cumsum() 
covid_df['total_tests']=covid_df.new_tests.cumsum()+initial_case

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#      total_cases  total_deaths  total_tests
# ...

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv', 
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x21112a40ed0>)

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
locations_df[locations_df.location=='Italy']
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %%
covid_df['location']='Italy'

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#      total_cases  total_deaths  total_tests location
# ...

# %% [markdown]
# We can now add the columns from locations_df into covid_df using the .merge method.

# %% [markdown]
# .merge('df_name','column_name')

# %%
merged_df = covid_df.merge(locations_df, on="location")

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# ...

# %%
merged_df['cases_per_million']=merged_df.total_cases* 1e6/merged_df.population
merged_df['deaths_per_million']=merged_df.total_deaths* 1e6/merged_df.population
merged_df['tests_per_million']=merged_df.total_tests* 1e6/merged_df.population

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# ...

# %% [markdown]
# Writting data back to files

# %%
result_df = merged_df[['date',
                       'new_cases', 
                       'total_cases', 
                       'new_deaths', 
                       'total_deaths', 
                       'new_tests', 
                       'total_tests', 
                       'cases_per_million', 
                       'deaths_per_million', 
                       'tests_per_million']]

# %%
result_df
# Out:
#           date  new_cases  total_cases  new_deaths  total_deaths  new_tests  \
# 0   2019-12-31        0.0          0.0         0.0           0.0        NaN
# 1   2020-01-01        0.0          0.0         0.0           0.0        NaN
# 2   2020-01-02        0.0          0.0         0.0           0.0        NaN
# 3   2020-01-03        0.0          0.0         0.0           0.0        NaN
# 4   2020-01-04        0.0          0.0         0.0           0.0        NaN
# ..         ...        ...          ...         ...           ...        ...
# 243 2020-08-30     1444.0     266853.0         1.0       35473.0    53541.0
# 244 2020-08-31     1365.0     268218.0         4.0       35477.0    42583.0
# 245 2020-09-01      996.0     269214.0         6.0       35483.0    54395.0
# 246 2020-09-02      975.0     270189.0         8.0       35491.0        NaN
# 247 2020-09-03     1326.0     271515.0         6.0       35497.0        NaN
#
# ...

# %% [markdown]
# .to_csv function also includes an additional column for storing the index of the dataframe by default. We pass #index=None to turn off this behavior. You can now verify that the results.csv is created and contains data from the data frame in CSV format:

# %%
result_df.to_csv('results.csv',index=False)

# %%
result_df.new_cases.plot()
# Out:
# <Axes: >

# %%
result_df.set_index('date',inplace=True)

# %%
result_df
# Out:
#             new_cases  total_cases  new_deaths  total_deaths  new_tests  \
# date
# 2019-12-31        0.0          0.0         0.0           0.0        NaN
# 2020-01-01        0.0          0.0         0.0           0.0        NaN
# 2020-01-02        0.0          0.0         0.0           0.0        NaN
# 2020-01-03        0.0          0.0         0.0           0.0        NaN
# 2020-01-04        0.0          0.0         0.0           0.0        NaN
# ...               ...          ...         ...           ...        ...
# 2020-08-30     1444.0     266853.0         1.0       35473.0    53541.0
# 2020-08-31     1365.0     268218.0         4.0       35477.0    42583.0
# 2020-09-01      996.0     269214.0         6.0       35483.0    54395.0
# 2020-09-02      975.0     270189.0         8.0       35491.0        NaN
# 2020-09-03     1326.0     271515.0         6.0       35497.0        NaN
#
#             total_tests  cases_per_million  deaths_per_million  \
# date
# ...

# %%
result_df.total_cases.plot()
result_df.total_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
death_rate=result_df.total_deaths/result_df.total_cases

# %%
death_rate.plot(title='Death Rate')
# Out:
# <Axes: title={'center': 'Death Rate'}, xlabel='date'>

# %%
positive_rates= result_df.total_cases/result_df.total_tests

# %%
positive_rates.plot(title='Positive Rate')
# Out:
# <Axes: title={'center': 'Positive Rate'}, xlabel='date'>

# %%
covid_month_df.new_cases.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>
